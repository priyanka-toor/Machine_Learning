# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

data=pd.read_excel('cust2.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ec-products     35 non-null     float64
#  1   Stationary      35 non-null     float64
#  2   fashion_prod    35 non-null     float64
#  3   other_shopping  35 non-null     float64
#  4   Savings         35 non-null     float64
# dtypes: float64(5)
# memory usage: 1.5 KB

# %%
corr_matrix=data[['Ec-products','Stationary','fashion_prod','other_shopping','Savings']].corr()
print(corr_matrix)
# Out:
#                 Ec-products  Stationary  fashion_prod  other_shopping  \
# Ec-products        1.000000    0.820644     -0.479381        0.227550
# Stationary         0.820644    1.000000      0.029120        0.542267
# fashion_prod      -0.479381    0.029120      1.000000        0.032551
# other_shopping     0.227550    0.542267      0.032551        1.000000
# Savings           -0.546897   -0.328027      0.762771       -0.599765
#
#                  Savings
# Ec-products    -0.546897
# Stationary     -0.328027
# fashion_prod    0.762771
# other_shopping -0.599765
# Savings         1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))  
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
